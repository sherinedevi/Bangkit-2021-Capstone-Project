# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import os
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from os import getcwd

# %%
# !unzip /content/drive/MyDrive/data_CNRPARK.zip
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: test/1/OVERCAST_2015-12-03_camera1_O_2015-12-03_09.11_C01_604.jpg
#   inflating: test/1/OVERCAST_2015-12-03_camera7_O_2015-12-03_16.20_C07_248.jpg
#   inflating: test/1/OVERCAST_2015-12-03_camera7_O_2015-12-03_14.50_C07_321.jpg
#   inflating: test/1/OVERCAST_2015-12-03_camera1_O_2015-12-03_14.41_C01_228.jpg
#   inflating: test/1/OVERCAST_2015-12-03_camera7_O_2015-12-03_15.20_C07_242.jpg
#   inflating: test/1/OVERCAST_2015-12-03_camera1_O_2015-12-03_09.41_C01_229.jpg
#   inflating: test/1/OVERCAST_2015-12-03_camera7_O_2015-12-03_16.20_C07_247.jpg
#   inflating: test/1/OVERCAST_2015-12-03_camera1_O_2015-12-03_12.41_C01_222.jpg
#   inflating: test/1/OVERCAST_2015-12-03_camera7_O_2015-12-03_16.20_C07_241.jpg
#   inflating: test/1/OVERCAST_2015-12-03_camera1_O_2015-12-03_12.11_C01_224.jpg
#   inflating: test/1/OVERCAST_2015-12-03_camera7_O_2015-12-03_12.50_C07_208.jpg
# ...

# %%
TRAIN_DIR='/content/train'
VAL_DIR='/content/validation'
TEST_DIR='/content/test'

# %%
# try out CNN model to tackle our problem
model=tf.keras.models.Sequential([
    tf.keras.layers.Conv2D(16, (3,3), input_shape=(150,150,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(16, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Conv2D(64, (3,3), activation='relu'),
    tf.keras.layers.MaxPooling2D(2,2),
    tf.keras.layers.Flatten(),
    # tf.keras.layers.Dropout(0.2),
    tf.keras.layers.Dense(256, activation='relu'),
    tf.keras.layers.Dense(1, activation='sigmoid')
])

model.compile(optimizer=tf.keras.optimizers.Adam(lr=0.001), loss='binary_crossentropy', metrics=['accuracy'])

# %%
train_datagen=ImageDataGenerator(1./255)
train_generator=train_datagen.flow_from_directory(
    TRAIN_DIR,
    target_size=(150,150),
    batch_size=64,
    class_mode='binary'
)
# Out:
# Found 27733 images belonging to 2 classes.

# %%
validation_datagen=ImageDataGenerator(1./255)
validation_generator=validation_datagen.flow_from_directory(
    VAL_DIR,
    target_size=(150,150),
    batch_size=64,
    class_mode='binary'
)
# Out:
# Found 7753 images belonging to 2 classes.

# %%
history=model.fit_generator(
    train_generator,
    epochs=10,
    verbose=1,
    validation_data=validation_generator
)
# Out:
# /usr/local/lib/python3.7/dist-packages/tensorflow/python/keras/engine/training.py:1844: UserWarning: `Model.fit_generator` is deprecated and will be removed in a future version. Please use `Model.fit`, which supports generators.
#   warnings.warn('`Model.fit_generator` is deprecated and '
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# Epoch 1/10
# 434/434 [==============================] - 35s 79ms/step - loss: 3.4174 - accuracy: 0.8999 - val_loss: 0.2000 - val_accuracy: 0.9418
# Epoch 2/10
# 434/434 [==============================] - 34s 78ms/step - loss: 0.0830 - accuracy: 0.9730 - val_loss: 0.1213 - val_accuracy: 0.9627
# Epoch 3/10
# ...

# %%
test_datagen=ImageDataGenerator(1./255)
test_generator=test_datagen.flow_from_directory(
    TEST_DIR,
    target_size=(150,150),
    batch_size=64,
    class_mode='binary'
)
# Out:
# Found 9097 images belonging to 2 classes.

# %%
loss,acc=model.evaluate(test_generator, verbose=2)
print(acc)
# Out:
# /usr/local/lib/python3.7/dist-packages/keras_preprocessing/image/image_data_generator.py:720: UserWarning: This ImageDataGenerator specifies `featurewise_center`, but it hasn't been fit on any training data. Fit it first by calling `.fit(numpy_data)`.
#   warnings.warn('This ImageDataGenerator specifies '
# 143/143 - 8s - loss: 0.1023 - accuracy: 0.9691
# 0.9691106677055359

# %%
model.save('/content/drive/MyDrive/models/saved_model/cnn02.h5')
